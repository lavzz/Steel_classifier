# %%
import save_bottleneck_features
# Out:
# Found 1200 images belonging to 6 classes.
# 10/10 [==============================] - 2s 195ms/step
# 0
# 10/10 [==============================] - 2s 180ms/step
# 1
# 10/10 [==============================] - 2s 167ms/step
# 2
# 10/10 [==============================] - 2s 167ms/step
# 3
# 10/10 [==============================] - 2s 171ms/step
# 4
# 10/10 [==============================] - 2s 174ms/step
# 5
# 10/10 [==============================] - 2s 167ms/step
# 6
# 10/10 [==============================] - 2s 182ms/step
# 7
# 10/10 [==============================] - 2s 177ms/step
# 8
# 10/10 [==============================] - 2s 206ms/step
# 9
# 10/10 [==============================] - 2s 190ms/step
# 10
# 10/10 [==============================] - 2s 232ms/step
# 11
# 10/10 [==============================] - 2s 187ms/step
# 12
# 10/10 [==============================] - 2s 185ms/step
# 13
# 10/10 [==============================] - 2s 167ms/step
# 14
# ...

# %%
import top_model
# Out:
# Train on 1200 samples, validate on 300 samples
# Epoch 1/10
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.4022 - acc: 0.8483 - val_loss: 0.3038 - val_acc: 0.8633
# Epoch 2/10
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.1538 - acc: 0.9517 - val_loss: 0.1341 - val_acc: 0.9600
# Epoch 3/10
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0875 - acc: 0.9742 - val_loss: 0.3078 - val_acc: 0.8900
# Epoch 4/10
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0892 - acc: 0.9642 - val_loss: 0.1395 - val_acc: 0.9433
# Epoch 5/10
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0510 - acc: 0.9842 - val_loss: 0.0966 - val_acc: 0.9700
# Epoch 6/10
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0578 - acc: 0.9817 - val_loss: 0.1770 - val_acc: 0.9267
# Epoch 7/10
# ...
